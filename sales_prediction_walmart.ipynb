# %%
import pandas as pd

# %%
! pip install numpy seaborn matplotlib klib dtale scikit-learn joblib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('Train.csv')
df_test = pd.read_csv('Test.csv')

# %%
df_train.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility
# 0           FDA15         9.30          Low Fat         0.016047  \
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier
# 0                  Dairy  249.8092            OUT049  \
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type
# 0                       1999      Medium               Tier 1  \
# 1                       2009      Medium               Tier 3
# ...

# %%
df_test.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods  \
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size
# 0  107.8622            OUT049                       1999      Medium  \
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
df_train.sample
# Out:
# <bound method NDFrame.sample of      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility
# 0              FDA15        9.300          Low Fat         0.016047  \
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier
# 0                     Dairy  249.8092            OUT049  \
# ...

# %%
df_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility
# 0              FDA15        9.300          Low Fat         0.016047  \
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier
# 0                     Dairy  249.8092            OUT049  \
# ...

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_train.shape
# Out:
# (8523, 12)

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  7060.000000      8523.000000  8523.000000                8523.000000  \
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df_train["Item_Weight"].describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df_train["Item_Weight"].fillna(df_train["Item_Weight"].mean(), inplace = True)
df_test["Item_Weight"].fillna(df_test["Item_Weight"].mean(), inplace=True)

# %%
df_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility
# 0              FDA15        9.300          Low Fat         0.016047  \
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier
# 0                     Dairy  249.8092            OUT049  \
# ...

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_train["Item_Weight"].describe()
# Out:
# count    8523.000000
# mean       12.857645
# std         4.226124
# min         4.555000
# 25%         9.310000
# 50%        12.857645
# 75%        16.000000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df_train["Outlet_Size"]
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          NaN
# 4         High
#          ...
# 8518      High
# 8519       NaN
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
df_train["Outlet_Size"].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
df_train["Outlet_Size"].fillna(df_train['Outlet_Size'].mode()[0], inplace = True)
df_test["Outlet_Size"].fillna(df_test["Outlet_Size"].mode()[0], inplace = True)

# %%
df_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  8523.000000      8523.000000  8523.000000                8523.000000  \
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df_train['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility
# 0           FDA15         9.30          Low Fat         0.016047  \
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier
# 0                  Dairy  249.8092            OUT049  \
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type
# 0                       1999      Medium               Tier 1  \
# 1                       2009      Medium               Tier 3
# ...

# %%
df_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type
# 0           FDW58    20.750000          Low Fat         0.007565  Snack Foods  \
# 1           FDW14     8.300000              reg         0.038428        Dairy
# 2           NCN55    14.600000          Low Fat         0.099575       Others
# 3           FDQ58     7.315000          Low Fat         0.015388  Snack Foods
# 4           FDY38    12.695633          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size
# 0  107.8622            OUT049                       1999      Medium  \
# 1   87.3198            OUT017                       2007      Medium
# 2  241.7538            OUT010                       1998      Medium
# 3  155.0340            OUT017                       2007      Medium
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# ### Feature Generation is not required so we will go with dimensionality reduction

# %% [markdown]
# ### Selecting features based on general requirements

# %%
df_train.drop(["Item_Identifier", "Outlet_Identifier"], axis = 1, inplace = True)
df_test.drop(["Item_Identifier", "Outlet_Identifier"], axis = 1, inplace = True)

# %%
df_train.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type
# 0         9.30          Low Fat         0.016047                  Dairy  \
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type
# 0  249.8092                       1999      Medium               Tier 1  \
# 1   48.2692                       2009      Medium               Tier 3
# 2  141.6180                       1999      Medium               Tier 1
# 3  182.0950                       1998      Medium               Tier 3
# 4   53.8614                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# ...

# %% [markdown]
# #### EDA

# %% [markdown]
# ### Feature Selection to find any outlier is present or not

# %% [markdown]
# ### EDA with DTALE Library

# %%
import dtale

# %%
dtale.show(df_train)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://bala-Latitude-E7470:40001/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### EDA using pandas profiling

# %%
! pip install pandas_profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.heatmap(df_train.corr(), annot = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/bala/Desktop/Sales Prediction/sales_prediction_walmart.ipynb Cell 40 line 1
# ----> <a href='vscode-notebook-cell:/home/bala/Desktop/Sales%20Prediction/sales_prediction_walmart.ipynb#Y100sZmlsZQ%3D%3D?line=0'>1</a> sns.heatmap(df_train.corr(), annot = True)
#       <a href='vscode-notebook-cell:/home/bala/Desktop/Sales%20Prediction/sales_prediction_walmart.ipynb#Y100sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...

# %% [markdown]
# ### EDA using KLIB Library

# %%
import klib

# %%
klib.cat_plot(df_train)
# Out:
# GridSpec(6, 5)

# %%
klib.corr_mat(df_train)
# Out:
# <style type="text/css">
# #T_28b4d_row0_col0, #T_28b4d_row0_col2, #T_28b4d_row0_col4, #T_28b4d_row1_col1, #T_28b4d_row2_col0, #T_28b4d_row2_col2, #T_28b4d_row2_col3, #T_28b4d_row2_col4, #T_28b4d_row3_col2, #T_28b4d_row3_col3, #T_28b4d_row4_col0, #T_28b4d_row4_col2, #T_28b4d_row4_col4 {
#   color: None;
# }
# #T_28b4d_row0_col1, #T_28b4d_row0_col3, #T_28b4d_row1_col0, #T_28b4d_row1_col2, #T_28b4d_row1_col3, #T_28b4d_row1_col4, #T_28b4d_row2_col1, #T_28b4d_row3_col0, #T_28b4d_row3_col1, #T_28b4d_row3_col4, #T_28b4d_row4_col1, #T_28b4d_row4_col3 {
#   color: #FF3344;
# }
# </style>
# <table id="T_28b4d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28b4d_level0_col0" class="col_heading level0 col0" >Item_Weight</th>
#       <th id="T_28b4d_level0_col1" class="col_heading level0 col1" >Item_Visibility</th>
#       <th id="T_28b4d_level0_col2" class="col_heading level0 col2" >Item_MRP</th>
# ...

# %%
klib.corr_plot(df_train)
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df_train)
# Out:
# <Axes: xlabel='Item_Weight', ylabel='Density'>

# %%
klib.missingval_plot(df_train)
# Out:
# No missing values found in the dataset.

# %% [markdown]
# ### Data Cleaning

# %%
klib.data_cleaning(df_train)
# Out:
# Shape of cleaned data: (8523, 10) - Remaining NAs: 0
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.46 MB (-70.77%)
#       item_weight item_fat_content  item_visibility              item_type
# 0        9.300000          Low Fat         0.016047                  Dairy  \
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# ...

# %%
klib.convert_datatypes(df_train) # Convert existing to more efficient dtypes, also called inside data_cleaning
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type
# 0        9.300000          Low Fat         0.016047                  Dairy  \
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# 8520    10.600000          Low Fat         0.035186     Health and Hygiene
# 8521     7.210000          Regular         0.145221            Snack Foods
# 8522    14.800000          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float64
#  1   Item_Fat_Content           8523 non-null   object
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   object
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Establishment_Year  8523 non-null   int64
#  6   Outlet_Size                8523 non-null   object
#  7   Outlet_Location_Type       8523 non-null   object
#  8   Outlet_Type                8523 non-null   object
#  9   Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 666.0+ KB

# %%
klib.mv_col_handling(df_train)
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type
# 0           9.300          Low Fat         0.016047                  Dairy  \
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
klib.pool_duplicate_subsets(df_train)
# Out:
#       Item_Visibility  Item_MRP  Item_Outlet_Sales  pooled_vars
# 0            0.016047  249.8092          3735.1380            0
# 1            0.019278   48.2692           443.4228            1
# 2            0.016760  141.6180          2097.2700            2
# 3            0.000000  182.0950           732.3800            3
# 4            0.000000   53.8614           994.7052            4
# ...               ...       ...                ...          ...
# 8518         0.056783  214.5218          2778.3834         8518
# 8519         0.046982  108.1570           549.2850         8519
# 8520         0.035186   85.1224          1193.1136         8520
# 8521         0.145221  103.1332          1845.5976         8521
# 8522         0.044878   75.4670           765.6700         8522
#
# [8523 rows x 4 columns]

# %%
df_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type
# 0           9.300          Low Fat         0.016047                  Dairy  \
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %% [markdown]
# ### Preprocessing Tasks befor Building a model

# %% [markdown]
# ### 1). Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df_train = df_train.apply(le.fit_transform)

# %%
df_train
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP
# 0             284                 1              664          4      5592  \
# 1              57                 2              880         14       473
# 2             376                 1              715         10      2901
# 3             393                 2                0          6      4227
# 4             265                 1                0          9       627
# ...           ...               ...              ...        ...       ...
# 8518          125                 1             3912         13      4955
# 8519          233                 2             3278          0      2023
# 8520          299                 1             2302          8      1263
# 8521          149                 2             7175         13      1857
# 8522          347                 1             3108         14      1011
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type
# ...

# %% [markdown]
# ### One Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()

# %%
X2 = pd.get_dummies(df_train, columns = ["Item_Fat_Content", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type"])

# %% [markdown]
# ### Splitting our Data into Train and Test

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_train.drop("Item_Outlet_Sales", axis = 1)
X
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP
# 0             284                 1              664          4      5592  \
# 1              57                 2              880         14       473
# 2             376                 1              715         10      2901
# 3             393                 2                0          6      4227
# 4             265                 1                0          9       627
# ...           ...               ...              ...        ...       ...
# 8518          125                 1             3912         13      4955
# 8519          233                 2             3278          0      2023
# 8520          299                 1             2302          8      1263
# 8521          149                 2             7175         13      1857
# 8522          347                 1             3108         14      1011
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type
# ...

# %%
Y = df_train["Item_Outlet_Sales"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 101, test_size = 0.2 )

# %%
Y_test
# Out:
# 8179     801
# 8355    2056
# 3411    1529
# 7089     779
# 6954    1858
#         ...
# 1317    1386
# 4996     808
# 531      356
# 3891    1144
# 6629    1839
# Name: Item_Outlet_Sales, Length: 1705, dtype: int64

# %%
Y_train
# Out:
# 3684     144
# 1935    1311
# 5142    1242
# 4978    1426
# 2299    2462
#         ...
# 599     3137
# 5695    1193
# 8006    1684
# 1361    2001
# 1547     746
# Name: Item_Outlet_Sales, Length: 6818, dtype: int64

# %% [markdown]
# ### 4). Standardization

# %%
X.describe()
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility    Item_Type
# count  8523.000000       8523.000000      8523.000000  8523.000000  \
# mean    298.756776          1.369354      3709.198639     7.226681
# std      95.451067          0.644810      2396.606857     4.209990
# min       0.000000          0.000000         0.000000     0.000000
# 25%     285.000000          1.000000      1595.500000     4.000000
# 50%     326.000000          1.000000      3708.000000     6.000000
# 75%     361.000000          2.000000      5789.500000    10.000000
# max     415.000000          4.000000      7879.000000    15.000000
#
#           Item_MRP  Outlet_Establishment_Year  Outlet_Size
# count  8523.000000                8523.000000  8523.000000  \
# mean   2941.096562                   3.790684     1.170832
# std    1675.483234                   2.730322     0.600327
# min       0.000000                   0.000000     0.000000
# 25%    1535.500000                   1.000000     1.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train_std = sc.fit_transform(X_train)

# %%
X_train_std
# Out:
# array([[ 1.00439018, -0.57382672,  0.96533577, ..., -1.95699503,
#          1.08786619, -0.25964107],
#        [-1.23760194, -0.57382672,  0.19186569, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        [ 1.01496562,  0.97378032,  0.29157407, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        ...,
#        [ 0.23238346, -0.57382672, -1.19862827, ...,  1.37953713,
#         -1.36527477, -0.25964107],
#        [-0.09545501,  0.97378032,  1.29992208, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        [ 0.62367454, -0.57382672,  1.53980627, ..., -0.28872895,
#          1.08786619,  0.98524841]])

# %%
X_test_std = sc.transform(X_test)

# %%
X_test_std
# Out:
# array([[ 0.07401316, -0.56892467,  0.05906162, ..., -0.26815662,
#          1.1067281 ,  1.07886076],
#        [ 0.84243117, -0.56892467, -0.42714573, ..., -1.92470387,
#          1.1067281 , -0.22387125],
#        [-1.08872462,  0.99561817,  0.50433399, ...,  1.38839063,
#         -1.38596862, -0.22387125],
#        ...,
#        [ 0.59977285, -0.56892467,  1.10499221, ..., -0.26815662,
#          1.1067281 , -1.52660325],
#        [ 0.7514343 , -0.56892467, -1.5344788 , ..., -0.26815662,
#          1.1067281 ,  1.07886076],
#        [-2.2211301 ,  0.99561817, -1.45553276, ..., -0.26815662,
#         -0.13962026, -0.22387125]])

# %%
Y_train
# Out:
# 3684     144
# 1935    1311
# 5142    1242
# 4978    1426
# 2299    2462
#         ...
# 599     3137
# 5695    1193
# 8006    1684
# 1361    2001
# 1547     746
# Name: Item_Outlet_Sales, Length: 6818, dtype: int64

# %%
Y_test
# Out:
# 8179     801
# 8355    2056
# 3411    1529
# 7089     779
# 6954    1858
#         ...
# 1317    1386
# 4996     808
# 531      356
# 3891    1144
# 6629    1839
# Name: Item_Outlet_Sales, Length: 1705, dtype: int64

# %% [markdown]
# ### Model Building

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train_std, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred_lr = lr.predict(X_test_std)

# %%
Y_test
# Out:
# 8179     801
# 8355    2056
# 3411    1529
# 7089     779
# 6954    1858
#         ...
# 1317    1386
# 4996     808
# 531      356
# 3891    1144
# 6629    1839
# Name: Item_Outlet_Sales, Length: 1705, dtype: int64

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
print(r2_score(Y_test, Y_pred_lr))
print(mean_absolute_error(Y_test, Y_pred_lr))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_lr)))
# Out:
# 0.5436711001713792
# 489.1673801165045
# 614.7302490085137

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=1000)

# %%
rf.fit(X_train, Y_train )
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
Y_pred_rf = rf.predict(X_test)

# %%
print(r2_score(Y_test, Y_pred_lr))
print(mean_absolute_error(Y_test, Y_pred_rf))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_rf)))
# Out:
# 0.5436711001713792
# 429.0237460410557
# 563.991362955571

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

# Define the model and parameters
model = RandomForestRegressor()
n_estimators = [10, 100, 1000]
max_depth = range(1, 31)
min_sample_leaf = np.linspace(0.1, 1.0)
max_features = ["auto", "sqrt", "log2"]
min_samples_split = np.linspace(0.1, 1.0, 10)

# Define the grid search
grid = dict(n_estimators = n_estimators)

cv = RepeatedStratifiedKFold(n_splits=5, n_repeats = 3, random_state = 101)
grid_search_forest = GridSearchCV(estimator = model, param_grid=grid, n_jobs = -1, scoring = 'r2', error_score = 0, verbose = 2, cv= 2)
grid_search_forest.fit(X_train_std, Y_train)

# Summarize results
print(f"Best: {grid_search_forest.best_score_:.3f} using {grid_search_forest.best_params_}")
means = grid_search_forest.cv_results_['mean_test_score']
stds = grid_search_forest.cv_results_['std_test_score']
params = grid_search_forest.cv_results_['params']

for mean, stddev, param in zip(means, stds, params):
    print(f"{mean:.3f}({stddev:.3f}) with {param}")
# Out:
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# [CV] END ....................................n_estimators=10; total time=   0.3s
# [CV] END ....................................n_estimators=10; total time=   0.3s
# [CV] END ...................................n_estimators=100; total time=   2.5s
# [CV] END ...................................n_estimators=100; total time=   2.6s
# [CV] END ..................................n_estimators=1000; total time=  24.2s
# [CV] END ..................................n_estimators=1000; total time=  24.7s
# Best: 0.622 using {'n_estimators': 1000}
# 0.590(0.005) with {'n_estimators': 10}
# 0.620(0.004) with {'n_estimators': 100}
# 0.622(0.003) with {'n_estimators': 1000}

# %%
grid_search_forest.best_params_
# Out:
# {'n_estimators': 1000}

# %%
grid_search_forest.best_score_
# Out:
# 0.6219994424693333

# %%
Y_pred_rf_grid = grid_search_forest.predict(X_test_std)

# %%
r2_score(Y_test, Y_pred_rf_grid)
# Out:
# 0.6215554855799661

# %% [markdown]
# ### Save the model

# %%
import joblib

# %%
joblib.dump(grid_search_forest, '/home/bala/Desktop/Sales Prediction/model/random_forest_grid.sav' )
# Out:
# ['/home/bala/Desktop/Sales Prediction/model/random_forest_grid.sav']

# %%
model = joblib.load('/home/bala/Desktop/Sales Prediction/model/random_forest_grid.sav')

# %%
model.predict(X_test_std)
# Out:
# array([1350.032, 2282.12 , 1062.681, ...,  330.85 , 1300.358, 1907.078])
